# %%
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= 100*np.array([[0.519235151243766,0.7215205453913407,0.7366701685154062],[0.6629912954548307,0.7936725216285697,0.8058344026382965],[0.7632356927835883,0.8078048914896334,0.8140611358149917]])    # gps,img,lidar,all 



df = pd.DataFrame(d, columns=['B-Twin','1R-Twin', '3R-Twin'])
print(df)
ax = plt.figure(figsize=(6,3)).add_subplot(111)

plots = df.plot(ax=ax, kind='bar',width=0.7,color=['#FBD6AB', '#D1D1D1','#2F5597'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
#     plots.annotate(format(bar.get_height(), '.2f'),(bar.get_x() + bar.get_width() ,bar.get_height()), ha='right', va='center',size=12, xytext=(0, 5),  weight='bold',textcoords='offset points')
#     ######################################
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.11), ncol=3,fontsize=14)
plt.xticks([0,1,2],['$\mathdefault{Acc_{(10,0)}}$', '$\mathdefault{Acc_{(10,1)}}$', '$\mathdefault{Acc_{(10,2)}}$'],fontsize=18,rotation=0)
plt.yticks(fontsize=18)
axes = plt.gca()
axes.set_ylim([50, 100])


plt.savefig('plots/DT-LOS.png',bbox_inches='tight',dpi=400)
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
#       B-Twin    1R-Twin    3R-Twin
# 0  31.989053  72.152055  73.667017
# 1  67.386411  79.367252  80.583440
# 2  81.465774  80.780489  81.406114
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_374975/3746022611.py in <cell line: 34>()
#      32
#      33
# ---> 34 plt.savefig('plots/DT-LOS.png',bbox_inches='tight',dpi=400)
#      35 plt.show()
#
# ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3326                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3327
# -> 3328             self.canvas.print_figure(fname, **kwargs)
#    3329
#    3330     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2360                 # force the figure dpi to 72), so we need to set it again here.
#    2361                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362                     result = print_method(
#    2363                         filename,
#    2364                         facecolor=facecolor,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2226                 "bbox_inches_restore"}
#    2227             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230         else:  # Let third-parties do as they see fit.
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685         pil_kwargs.setdefault("format", format)
#    1686         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687         image.save(fname, **pil_kwargs)
#    1688
#    1689
#
# ~/.local/lib/python3.10/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2408                 fp = builtins.open(filename, "r+b")
#    2409             else:
# -> 2410                 fp = builtins.open(filename, "w+b")
#    2411
#    2412         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/DT-LOS.png'
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# d= 100*np.array([[0.585930117,0.773015595,0.833195609],[0.746200108,0.826989243,0.862120697],[0.798447524,0.861584815,0.873762517]])    # gps,img,lidar,all 
d= 100*np.array([[0.5847887543792298,0.8054747117726306,0.8326093451441972],[0.7447611846391862,0.8637249671652514,0.8836916601230002],[0.7962891387149533,0.8813188299575495,0.8902322355954077]])    # gps,img,lidar,all 



df = pd.DataFrame(d, columns=['B-Twin','1R-Twin', '3R-Twin'])
print(df)
ax = plt.figure(figsize=(6,3)).add_subplot(111)

plots = df.plot(ax=ax, kind='bar',width=0.7,color=['#FBD6AB', '#D1D1D1','#2F5597'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
#     plots.annotate(format(bar.get_height(), '.2f'),(bar.get_x() + bar.get_width() ,bar.get_height()), ha='right', va='center',size=12, xytext=(0, 5),  weight='bold',textcoords='offset points')
#     ######################################
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.11), ncol=3,fontsize=14)
plt.xticks([0,1,2],['$\mathdefault{Acc_{(10,0)}}$', '$\mathdefault{Acc_{(10,1)}}$', '$\mathdefault{Acc_{(10,2)}}$'],fontsize=18,rotation=0)
plt.yticks(fontsize=18)
axes = plt.gca()
axes.set_ylim([50, 100])


plt.savefig('plots/DT-NLOS.png',bbox_inches='tight',dpi=400)
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
#       B-Twin    1R-Twin    3R-Twin
# 0  58.478875  80.547471  83.260935
# 1  74.476118  86.372497  88.369166
# 2  79.628914  88.131883  89.023224
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2414705/1108421601.py in <cell line: 35>()
#      33
#      34
# ---> 35 plt.savefig('plots/DT-NLOS.png',bbox_inches='tight',dpi=400)
#      36 plt.show()
#
# ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3326                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3327
# -> 3328             self.canvas.print_figure(fname, **kwargs)
#    3329
#    3330     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2360                 # force the figure dpi to 72), so we need to set it again here.
#    2361                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362                     result = print_method(
#    2363                         filename,
#    2364                         facecolor=facecolor,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2226                 "bbox_inches_restore"}
#    2227             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230         else:  # Let third-parties do as they see fit.
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685         pil_kwargs.setdefault("format", format)
#    1686         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687         image.save(fname, **pil_kwargs)
#    1688
#    1689
#
# ~/.local/lib/python3.10/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2408                 fp = builtins.open(filename, "r+b")
#    2409             else:
# -> 2410                 fp = builtins.open(filename, "w+b")
#    2411
#    2412         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/DT-NLOS.png'
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
